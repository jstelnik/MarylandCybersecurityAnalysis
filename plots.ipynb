# %%
import pandas as pd 
import json
import numpy as np
import matplotlib.pyplot as plt

myData = pd.read_csv("Results314Edited.csv")

myData = myData.drop([0,1])

myData2 = myData.copy(deep=True)

Q12_answers={"I do not use multifactor authentication.":1,
"I use multifactor authentication on my important online accounts.":2,
"I use multifactor authentication on most of my online accounts.":3,
"I use multifactor authentication wherever it is offered to me.":4,
"I don’t know.":0}


myData["Q12"].fillna("I don't know")
# myData2["Q12"] = 0
# for key in Q12_answers.keys():
#     myData2.loc[myData['Q12'].str.contains(key, na=False), 'Q12'] += Q12_answers[key]

Q15_answers={"I do not use multifactor authentication":1,
"Messages sent to my phone that contain a code":2,
"An application on my phone that verifies I am logging in":2,
"An application that generates a one-time code":2,
"A hardware security token (e.g., YubiKey or Google Titan)":2,
"I don’t know.":0}

myData["Q15"].fillna("I don't know")
sQ15 = myData['Q15'].str.split(';').explode().value_counts().to_frame('Count')
# myData2["Q15"] = 0
# for key in Q15_answers.keys():
#     myData2.loc[myData['Q15'].str.contains(key, na=False), 'Q15'] += Q15_answers[key]

Q16_answers={"I use the same password for all of my accounts":1,
"I use the same password for most of my accounts":2,
"I use passwords that are similar but different for all of my accounts":3,
"I use personal information (names of pets, children, or friends) as all or part of my password":4,
"I use a unique complex password for my accounts":5,
"I don’t know.":0}

myData["Q16"].fillna("I don't know")
sQ16 = myData['Q16'].str.split(';').explode().value_counts().to_frame('Count')
# myData2["Q16"] = 0
# for key in Q16_answers.keys():
#     myData2.loc[myData['Q16'].str.contains(key, na=False), 'Q16'] += Q16_answers[key]

Q17_answers={"I remember my passwords":1,
"I write my passwords down":2,
"I use a password manager":3,
"I don’t know":0}


myData["Q17"].fillna("I don't know")
sQ17 = myData['Q17'].str.split(';').explode().value_counts().to_frame('Count')
# myData2["Q17"] = 0
# for key in Q17_answers.keys():
#     myData2.loc[myData['Q17'].str.contains(key, na=False), 'Q17'] += Q17_answers[key]

Q18_answers={"I have never received security awareness training.":1,
"I have received security awareness training within the past month":5,
"I have received security awareness training within the past 6 months":4,
"I have received security awareness training within the past year":3,
"I have received security awareness training a year or more ago":2,
"I don’t know.":0}


myData["Q18"].fillna("I don't know")
# myData2["Q18"] = 0
# for key in Q18_answers.keys():
#     myData2.loc[myData['Q18'].str.contains(key, na=False), 'Q18'] = Q18_answers[key]

History_answers = {"Yes":2, "No":1,"I don't know":0}

myData["Q19"].fillna("I don't know")
# myData2["Q19"] = 0
# for key in History_answers.keys():
#     myData2.loc[myData['Q19'].str.contains(key, na=False), 'Q19'] = History_answers[key]

myData["Q20"].fillna("I don't know")
# myData2["Q20"] = 0
# for key in History_answers.keys():
#     myData2.loc[myData['Q20'].str.contains(key, na=False), 'Q20'] = History_answers[key]

myData["Q21"].fillna("I don't know")
# myData2["Q21"] = 0
# for key in History_answers.keys():
#     myData2.loc[myData['Q21'].str.contains(key, na=False), 'Q21'] = History_answers[key]

myData["Q25"].fillna("I don't know")
# myData2["Q25"] = 0
# for key in History_answers.keys():
#     myData2.loc[myData['Q25'].str.contains(key, na=False), 'Q25'] = History_answers[key]

myData["Q26"].fillna("I don't know")
# myData2["Q26"] = 0
# for key in History_answers.keys():
#     myData2.loc[myData['Q26'].str.contains(key, na=False), 'Q26'] = History_answers[key]

myData["Q27"].fillna("I don't know")
# myData2["Q27"] = 0
# for key in History_answers.keys():
#     myData2.loc[myData['Q27'].str.contains(key, na=False), 'Q27'] = History_answers[key]

Scale_agree_answers={"Strongly disagree":0, "Somewhat disagree":1, "Neither agree nor disagree":2, "Somewhat agree":3, "Strongly agree":4}
Scale_likely_answers = {"Extremely unlikely":5, "Somewhat unlikely":4, "Neither likely nor unlikely":3, "Somewhat likely":2, "Extremely likely":1, "I don't know":0}

myData["Q28"].fillna("I don't know")
# myData2["Q28"] = 0
# for key in Scale_likely_answers.keys():
#     myData2.loc[myData['Q28'].str.contains(key, na=False), 'Q28'] = Scale_likely_answers[key]

myData["Q29"].fillna("Neither agree nor disagree")
# myData2["Q29"] = 0
# for key in Scale_agree_answers.keys():
#     myData2.loc[myData['Q29'].str.contains(key, na=False), 'Q29'] = Scale_agree_answers[key]

myData["Q31"].fillna("Neither agree nor disagree")
# myData2["Q31"] = 0
# for key in Scale_agree_answers.keys():
#     myData2.loc[myData['Q31'].str.contains(key, na=False), 'Q31'] = Scale_agree_answers[key]

Q5_answers = {"I use a cloud service (e.g., Microsoft OneDrive, Carbonite, Google Drive)":5,
"I use removable storage that I keep in my house":4,
"I use removable storage that I keep in a location other than my house":3,
"I use keep multiple copies of my files on my computer":2,
"I do not back up my data":1,
"I don’t know}":0}

myData["Q5"].fillna("I don't know")
sQ5 = myData['Q5'].str.split(';').explode().value_counts().to_frame('Count')
# myData2["Q5"] = 0
# for key in Q5_answers.keys():
#     myData2.loc[myData['Q5'].str.contains(key, na=False), 'Q5'] += Q5_answers[key]

Q6_answers = {"Continuously":7,
"Daily":6,
"Weekly":5,
"Monthly":4,
"Less often than monthly but at least once a year":3,
"Once a year or less frequently":2,
"I do not back up my data":1,
"I don’t know":0}


myData["Q6"].fillna("I don't know")
sQ6 = myData['Q6'].str.split(';').explode().value_counts().to_frame('Count')
# myData2["Q6"] = 0
# for key in Q6_answers.keys():
#     myData2.loc[myData['Q6'].str.contains(key, na=False), 'Q6'] += Q6_answers[key]

Q7_answers = {"Within a day":6,
"Within in a week":5,
"Within a month":4,
"Within a year":3,
"More than a year ago":2,
"I do not back up my data":1,
"I don’t know":0}


myData["Q7"].fillna("I don't know")
# myData2["Q7"] = 0
# for key in Q7_answers.keys():
#     myData2.loc[myData['Q7'].str.contains(key, na=False), 'Q7'] = Q7_answers[key]
# Out:
# 2         Within a year
# 3      Within in a week
# 4      Within in a week
# 5      Within in a week
# 6      Within in a week
#              ...
# 546    Within in a week
# 547        Within a day
# 548       Within a year
# 549    Within in a week
# 550      Within a month
# Name: Q7, Length: 549, dtype: object

# %%
# demographics: age, education, county and how they mesh
# for maryland purposes, useful to sum up the numbers from the big 7 counties
# compare counties to state totals, everything (ex: if 1% of respondents are from a county, but that county has 5% of state population)
# compare every dimension of demographic to the state
# instead of raw numbers, use percentages
# use maryland 2020 census
# we may want to look at correlations
# represent the good bad and ugly
# make clear in report
# future research question in report that says we acknowledge it doesn't take sample but shows a need for a survey that does
# how do you collect the survey for this?
# our lack of familiarity with survey taking
# shocking findings that didn't expect to see
# instead of creating functions and averages, put raw data in graphical form, sliced and diced
# not just 1d charts but also 2d charts so we can see what that yields
# next step: 3d charts?
# get better feel for 1d and 2d raw data first
# look at n^2 graphs (?) and then we can trim them down
# send something tomorrow
# meet weekly
# send the thing

# %%
myData = myData.replace('65-75', '65 years or older').replace("75 years or older", "65 years or older")
dataToPlot = myData.groupby('Q1').RandomSurveyID.count()
ax = dataToPlot.plot.bar(rot=90);
plt.ylabel("Number of Participants")
plt.xlabel("Age")
plt.title("Age (select one):")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')


plt.savefig("Q1.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q2').RandomSurveyID.count()
ax = dataToPlot.plot.bar(rot=90);
plt.ylabel("Number of Participants")
plt.xlabel("County")
plt.title("Please select the jurisdiction of your primary residence:")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q2County.png", bbox_inches="tight")
plt.show()

# %%
regions = {"Frederick County":"Capital Region", "Montgomery County":"Capital Region", "Prince George's County":"Capital Region", 
        "Anne Arundel County":"Central Maryland", "Baltimore City":"Central Maryland", "Baltimore County":"Central Maryland", "Carroll County":"Central Maryland", "Cecil County":"Central Maryland", "Harford County":"Central Maryland", "Howard County":"Central Maryland", 
        "Caroline County":"Eastern Shore of Maryland", "Dorchester County":"Eastern Shore of Maryland", "Kent County":"Eastern Shore of Maryland", "Queen Anne's County":"Eastern Shore of Maryland", "Somerset County":"Eastern Shore of Maryland", "Talbot County":"Eastern Shore of Maryland", "Wicomico County":"Eastern Shore of Maryland", "Worcester County":"Eastern Shore of Maryland",
        "Calvert County":"Southern Maryland", "Charles County":"Southern Maryland", "St. Mary's County":"Southern Maryland",
        "Allegany County":"Western Maryland", "Garrett County":"Western Maryland", "Washington County":"Western Maryland"}
regionData = myData.replace(regions, regex=True)
dataToPlot = regionData.groupby('Q2').RandomSurveyID.count()
ax = dataToPlot.plot.bar(rot=90);
plt.ylabel("Number of Participants")
plt.xlabel("Region")
plt.title("Please select the jurisdiction of your primary residence: (region)")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q2Region.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q3').RandomSurveyID.count()
x_order = [ "Do not have a HS Diploma or GED", "High School Diploma or GED", "Some College", "Associates Degree", "Bachelor’s Degree", "Graduate Degree"]
ax = dataToPlot.loc[x_order].plot.bar(rot=90)
plt.ylabel("Number of Participants")
plt.xlabel("Level of Education")
plt.title("Education Level (Select One):")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q3.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby((myData.Q4.astype(int))//10 * 10).RandomSurveyID.count()
                
ax = dataToPlot.plot.bar(rot=90);
plt.ylabel("Number of Participants")
plt.xlabel("Decade of Birth")
plt.title("What decade were you born?")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q4.png", bbox_inches="tight")
plt.show()

# %%
print(len(sQ5.index))
bar_graph_dict = sQ5.to_dict()['Count']
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(sQ5.index.unique(), bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.title("How do you backup your data? (Check All that apply)")
plt.xlabel("Ways to Backup Data")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q5.png", bbox_inches="tight")
plt.show()
# Out:
# 6

# %%
# x_order = [ "I don’t know", "I do not back up my data", "Once a year or less frequently", "Less often than monthly but at least once a year", "Monthly", "Weekly", "Daily", "Continuously"]
# ax = sQ6.loc[x_order].plot.bar(rot=90);
# plt.ylabel("Number of Participants")
# plt.title("How often do you back up your data? (Check all that apply)")
# plt.xlabel("Time Increments")
# plt.legend('', frameon=False)

# heightlst = []
# for i in ax.patches:
#     heightlst.append(i.get_height())
# total = sum(heightlst)

# for i in ax.patches:
#     height = i.get_height()
#     value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
#     ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

# plt.savefig("Q6.png", bbox_inches="tight")
# plt.show()

bar_graph_dict = sQ6.to_dict()['Count']
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(sQ6.index.unique(), bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.title("How often do you back up your data? (Check all that apply)")
plt.xlabel("Time Increments")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q6.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q7').RandomSurveyID.count()
x_order = ["I don’t know", "I do not back up my data", "More than a year ago", "Within a year", "Within a month", "Within in a week", "Within a day"]
ax = dataToPlot.loc[x_order].plot.bar(rot=90)
plt.ylabel("Number of Participants")
plt.xlabel("Time Increments")
plt.title("When was the last time you made sure your backups were valid?")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q7.png", bbox_inches="tight")
plt.show()

# %%
x_order = ["Any action in which someone tries to convince another person to take an action which may not be in their best interests", "Actively trying to circumvent or get around security safeguards by finding weaknesses in a system that can be exploited without personal interaction", "Attempting to inform people about the use of proper security policies, processes, and procedures", "When a company makes a public announcement about something positive that has happened or is going to happen", "I don’t know"]
dataToPlot = myData.groupby('Q8').RandomSurveyID.count()
bar_graph_dict = dataToPlot.loc[x_order].to_dict()
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(x_order, bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.xlabel("Participant Answer")
plt.title("What is Social Engineering in an information security context?")

for patch in ax.patches:
    patch.set_hatch('//')
    break

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q8.png", bbox_inches="tight")
plt.show()

# %%
# colors = ['g', 'b', 'b', 'b', 'b']
# dataToPlot = myData.groupby('Q9').RandomSurveyID.count()
x_order = ['When someone fraudulently sends a specifically crafted message to a person to convince them to take an action which may harm them','Targeted marketing emails sent to a specific person by a company based on their buying history or web browsing habits','When someone sends an email specifically designed to belittle the recipient','When someone in a business setting sends an email to a coworker inappropriately delegating their work to the recipient','I don’t know']
# ax = dataToPlot.loc[x_order].plot.bar(color=colors,rot=90);
# plt.ylabel("Number of Participants")
# plt.xlabel("Participant Answer")
# plt.title("What is Spear Phishing?")

# heightlst = []
# for i in ax.patches:
#     heightlst.append(i.get_height())
# total = sum(heightlst)

# for i in ax.patches:
#     height = i.get_height()
#     value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
#     ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

# plt.savefig("Q9.png", bbox_inches="tight")
# plt.show()

dataToPlot = myData.groupby('Q9').RandomSurveyID.count()
bar_graph_dict = dataToPlot.loc[x_order].to_dict()
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(x_order, bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.xlabel("Participant Answer")
plt.title("What is Spear Phishing?")

for patch in ax.patches:
    patch.set_hatch('//')
    break

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q9.png", bbox_inches="tight")
plt.show()

# %%
x_order = ['When a someone fraudulently sends email to people to convince them to take an action which may harm them', 'When companies or individuals send out emails to promote or sell their products','When someone you know sends an email that was forwarded to you encouraging you to forward that message on to everyone in your address book','When someone sends an email to a large group of people and one of the recipients replies with a personal response to all recipients of the original email','I don’t know']
dataToPlot = myData.groupby('Q10').RandomSurveyID.count()
bar_graph_dict = dataToPlot.loc[x_order].to_dict()
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(x_order, bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.xlabel("Participant Answer")
plt.title("What is Phishing?")

for patch in ax.patches:
    patch.set_hatch('//')
    break

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q10.png", bbox_inches="tight")
plt.show()

# %%
x_order = ['An additional piece of information beyond username and password which someone must provide to gain access to a system (e.g., website)','The Frequent changing of a passwords so it is harder for an attacker to guess','Adding different numbers to the ends of a usernames so a user never has the same username on multiple sites','When someone uses a different password for each web site they access','I don’t know']
dataToPlot = myData.groupby('Q11').RandomSurveyID.count()
bar_graph_dict = dataToPlot.loc[x_order].to_dict()
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(x_order, bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.xlabel("Participant Answer")
plt.title("What is Multifactor Authentication?")

for patch in ax.patches:
    patch.set_hatch('//')
    break

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q11.png", bbox_inches="tight")
plt.show()

# %%
x_order = ["I do not use multifactor authentication.", "I use multifactor authentication on my important online accounts.", "I use multifactor authentication on most of my online accounts.", "I use multifactor authentication wherever it is offered to me.", "I don’t know."]
dataToPlot = myData.groupby('Q12').RandomSurveyID.count()
bar_graph_dict = dataToPlot.loc[x_order].to_dict()
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(x_order, bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.xlabel("Participant Answer")
plt.title("Where do you use multifactor authentication? (Select one)?")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q12Bar.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q12').RandomSurveyID.count()
labels = ["I do not use multifactor authentication.", "I use multifactor authentication on my important online accounts.", "I use multifactor authentication on most of my online accounts.", "I use multifactor authentication wherever it is offered to me.",
"I don’t know."]
ax = dataToPlot.plot(kind="pie", startangle=90, autopct="%.1f%%", labeldistance=None, ylabel='', pctdistance=.6)
ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
plt.title('Where do you use multifactor authentication? (Select one)?')

plt.savefig("Q12Pie.png", bbox_inches="tight")
plt.show()

# %%
bar_graph_dict = sQ15.to_dict()['Count']
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(sQ15.index.unique(), bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.title("What form of multifactor authentication do you use? (Check all that apply)")
plt.xlabel("Where to Use Multifactor Authentication")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q15.png", bbox_inches="tight")
plt.show()

# %%
bar_graph_dict = sQ16.to_dict()['Count']
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(sQ16.index.unique(), bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.title("How do you choose a password for your online accounts? (Check all that apply)")
plt.xlabel("How Passwords Are Chosen")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q16.png", bbox_inches="tight")
plt.show()

# %%
bar_graph_dict = sQ17.to_dict()['Count']
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(sQ17.index.unique(), bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.title("How do you manage the passwords for your online accounts? (Check all that apply)")
plt.xlabel("How to Manage Passwords")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q17.png", bbox_inches="tight")
plt.show()

# %%
x_order=["I have never received security awareness training.",
"I have received security awareness training within the past month",
"I have received security awareness training within the past 6 months",
"I have received security awareness training within the past year",
"I have received security awareness training a year or more ago",
"I don’t know."]
dataToPlot = myData.groupby('Q18').RandomSurveyID.count()
bar_graph_dict = dataToPlot.loc[x_order].to_dict()
df = pd.DataFrame(bar_graph_dict, index=[""])
ax = df.plot(kind="bar", width=4)
plt.legend(x_order, bbox_to_anchor=(1.0, 1.0))
plt.ylabel("Number of Participants")
plt.title("When have you ever received security awareness training \nat your place of employment or through other means \nsuch as a community organization or an advocacy group?")
plt.xlabel("Possible Answers")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q18.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q19').RandomSurveyID.count()
x_order = [ "Yes", "No", "I don't know"]
ax = dataToPlot.loc[x_order].plot.bar(rot=90)
plt.ylabel("Number of Participants")
plt.xlabel("Possible Answers")
plt.title('Have you ever been the victim of ransomware?')

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q19.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q20').RandomSurveyID.count()
x_order = [ "Yes", "No", "I don't know"]
ax = dataToPlot.loc[x_order].plot.bar(rot=90)
plt.ylabel("Number of Participants")
plt.xlabel("Possible Answers")
plt.title('To your knowledge, has your personal information \nbeen disclosed to unauthorized people, e.g., via a data breach?')

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q20.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q21').RandomSurveyID.count()
x_order = [ "Yes", "No", "I don't know"]
ax = dataToPlot.loc[x_order].plot.bar(rot=90)
plt.ylabel("Number of Participants")
plt.xlabel("Possible Answers")
plt.title('Have you ever been the victim of an online scam \nwhere you lost any amount of money?')

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q21.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby((myData.Q24.astype(float))//100 * 100).RandomSurveyID.count()
ax = dataToPlot.plot.bar(x='Q24', y='SecuritySum', rot=90);
plt.ylabel("Number of Participants")
plt.title("If so, about how much money did you lose as a victim of this scam \n(enter 0 if you have not lost any money)?")
plt.xlabel("Money ($)")
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

#heightlst = []
#for i in ax.patches:
    #heightlst.append(i.get_height())
#total = sum(heightlst)

#for i in ax.patches:
    #height = i.get_height()
    #value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    #ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')


plt.savefig("Q24With0.png", bbox_inches="tight")
plt.show()
# including all 0 answers

# %%
myData2.Q24 = myData.Q24.astype(float)
dataToPlot = myData.loc[myData2.Q24 > 0].groupby((myData.Q24.astype(float)//100 + 1) * 100).RandomSurveyID.count()
ax = dataToPlot.plot.bar(x='Q24', y='SecuritySum', rot=90);
plt.ylabel("Number of Participants")
plt.title("If so, about how much money did you lose as a victim of this scam \n(enter 0 if you have not lost any money)? \n(not including $0)")
plt.xlabel("Money ($)")
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
    
#heightlst = []
#for i in ax.patches:
    #heightlst.append(i.get_height())
#total = sum(heightlst)

#for i in ax.patches:
    #height = i.get_height()
    #value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    #ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')


plt.savefig("Q24Without0.png", bbox_inches="tight")
plt.show()
# not including 0 answers

# %%
dataToPlot = myData.groupby('Q25').RandomSurveyID.count()
x_order = [ "Yes", "No", "I don't know"]
ax = dataToPlot.loc[x_order].plot.bar(rot=90)
plt.ylabel("Number of Participants")
plt.xlabel("Possible Answers")
plt.title('Have you ever been targeted by a scammer \nwho called you directly on the phone?')

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q25.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q26').RandomSurveyID.count()
x_order = [ "Yes", "No", "I don't know"]
ax = dataToPlot.loc[x_order].plot.bar(rot=90)
plt.ylabel("Number of Participants")
plt.xlabel("Possible Answers")
plt.title('Have you ever lost access to any of your\n online accounts due to someone else taking it over?')

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q26.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q27').RandomSurveyID.count()
x_order = [ "Yes", "No", "I don't know"]
ax = dataToPlot.loc[x_order].plot.bar(rot=90)
plt.ylabel("Number of Participants")
plt.xlabel("Possible Answers")
plt.title('Have you ever received an email claiming \nto be from a financial institution you use that asks you \nto log in to that account to resolve some issue?')

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q27.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q28').RandomSurveyID.count()
x_order = ["I don't know", "Extremely unlikely", "Somewhat unlikely", "Neither likely nor unlikely", "Somewhat likely", "Extremely likely"]
ax = dataToPlot.loc[x_order].plot.bar(x='Q28', y='SecuritySum', rot=90)
plt.ylabel("Number of Participants")
plt.title("How likely do you think you are to be targeted \nby a malicious actor (Hacker) at some time in the future?")
plt.xlabel("Possible Answers")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q28.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q29').RandomSurveyID.count()
x_order = ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"]
ax = dataToPlot.loc[x_order].plot.bar(x='Q29', y='SecuritySum', rot=90)
plt.ylabel("Number of Participants")
plt.title("I am very confident with my computer skills")
plt.xlabel("5 Answer Scale")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q29.png", bbox_inches="tight")
plt.show()

# %%
dataToPlot = myData.groupby('Q31').RandomSurveyID.count()
x_order = ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"]
ax = dataToPlot.loc[x_order].plot.bar(x='Q31', y='SecuritySum', rot=90)
plt.ylabel("Number of Participants")
plt.title("I am knowledgeable about cybersecurity")
plt.xlabel("5 Answer Scale")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("Q31.png", bbox_inches="tight")
plt.show()

# %%
from itertools import combinations
regionData = myData.replace(regions, regex=True)
# for now drop all columns that have check all that apply, so crosstabs are done for everything else
regionData = regionData.drop(columns=["ResponseId", "Q5", "Q6", "Q15", "Q16", "Q17", "Q4", "Q24"], axis=1)
loopData = regionData.merge(regionData, on="RandomSurveyID")
pairwise_combos = list(combinations(regionData.columns, 2))
crosstabs = []
dict = {"Q1": ['18-24','25-34','35-44','45-54','55-64','65 years or older'], 
        "Q2": ["Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", 'I don’t know'],
       "Q3": ['Do not have a HS Diploma or GED', 'High School Diploma or GED', 'Associates Degree','Some College', 'Bachelor’s Degree', 'Graduate Degree'], "Q7": ["Within in a week","Within a month","Within a year","More than a year ago","I do not back up my data","I don’t know"],
       "Q8": ["Any action in which someone tries to convince another person to take an action which may not be in their best interests",
"Actively trying to circumvent or get around security safeguards by finding weaknesses in a system that can be exploited without personal interaction",
"Attempting to inform people about the use of proper security policies, processes, and procedures",
"When a company makes a public announcement about something positive that has happened or is going to happen",
"I don’t know"], "Q9": ["When someone fraudulently sends a specifically crafted message to a person to convince them to take an action which may harm them",
"Targeted marketing emails sent to a specific person by a company based on their buying history or web browsing habits",
"When someone sends an email specifically designed to belittle the recipient",
"When someone in a business setting sends an email to a coworker inappropriately delegating their work to the recipient",
"I don’t know"], "Q10" : ["When a someone fraudulently sends email to people to convince them to take an action which may harm them",
"When companies or individuals send out emails to promote or sell their products",
"When someone you know sends an email that was forwarded to you encouraging you to forward that message on to everyone in your address book",
"When someone sends an email to a large group of people and one of the recipients replies with a personal response to all recipients of the original email",
"I don’t know"], "Q11" : ['An additional piece of information beyond username and password which someone must provide to gain access to a system (e.g., website)',
"The Frequent changing of a passwords so it is harder for an attacker to guess",
"Adding different numbers to the ends of a usernames so a user never has the same username on multiple sites",
"When someone uses a different password for each web site they access",
"I don’t know"], "Q12" : ["I do not use multifactor authentication.",
"I use multifactor authentication on my important online accounts.",
"I use multifactor authentication on most of my online accounts.",
"I use multifactor authentication wherever it is offered to me.",
"I don’t know."], "Q18" : ["I have never received security awareness training.",
"I have received security awareness training within the past month",
"I have received security awareness training within the past 6 months",
"I have received security awareness training within the past year",
"I have received security awareness training a year or more ago",
"I don’t know."], "Q19" : ["Yes", "No", "I don't know"], "Q20" : ["Yes", "No", "I don't know"], "Q21" : ["Yes", "No", "I don't know"], "Q25" : ["Yes", "No", "I don't know"], "Q26" : ["Yes", "No", "I don't know"], "Q27" : ["Yes", "No", "I don't know"], "Q31" : ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"], "Q29" : ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"], 
        "Q28" : ["Extremely unlikely", "Somewhat unlikely", "Neither likely nor unlikely", "Somewhat likely", "Extremely likely", "I don't know"]}
for i in pairwise_combos:
    if i[0] != 'RandomSurveyID' and i[1] != 'RandomSurveyID':
        newCrossTab = pd.crosstab(loopData[i[0] + '_x'], loopData[i[1]+'_y'],margins=True, margins_name="Total", normalize="index").rename_axis(index=None, columns=None) * 100
        newCrossTab = newCrossTab.round(2)
        newCrossTab = newCrossTab.astype(str)
        newCrossTab = newCrossTab + " %"
        newCrossTab = newCrossTab.reindex(dict[i[0]], axis="rows")
        newCrossTab = newCrossTab.reindex(dict[i[1]], axis="columns")
        newCrossTab = newCrossTab.style.set_caption("Comparison of " + i[0] + " with " + i[1])
        crosstabs.append(newCrossTab)

# %%
#from IPython.display import display
#for i in range(len(crosstabs)):
    #display(crosstabs[i])

# %%
from itertools import combinations
regionData = myData.replace(regions, regex=True)
# for now drop all columns that have check all that apply, so crosstabs are done for everything else
regionData = regionData.drop(columns=["ResponseId", "Q5", "Q6", "Q15", "Q16", "Q17", "Q4", "Q24"], axis=1)
loopData = regionData.merge(regionData, on="RandomSurveyID")
pairwise_combos = list(combinations(regionData.columns, 2))
crosstabs = []
dict = {"Q1": ['18-24','25-34','35-44','45-54','55-64','65 years or older'], 
        "Q2": ["Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", 'I don’t know'],
       "Q3": ['Do not have a HS Diploma or GED', 'High School Diploma or GED', 'Associates Degree','Some College', 'Bachelor’s Degree', 'Graduate Degree'], "Q7": ["Within in a week","Within a month","Within a year","More than a year ago","I do not back up my data","I don’t know"],
       "Q8": ["Any action in which someone tries to convince another person to take an action which may not be in their best interests",
"Actively trying to circumvent or get around security safeguards by finding weaknesses in a system that can be exploited without personal interaction",
"Attempting to inform people about the use of proper security policies, processes, and procedures",
"When a company makes a public announcement about something positive that has happened or is going to happen",
"I don’t know"], "Q9": ["When someone fraudulently sends a specifically crafted message to a person to convince them to take an action which may harm them",
"Targeted marketing emails sent to a specific person by a company based on their buying history or web browsing habits",
"When someone sends an email specifically designed to belittle the recipient",
"When someone in a business setting sends an email to a coworker inappropriately delegating their work to the recipient",
"I don’t know"], "Q10" : ["When a someone fraudulently sends email to people to convince them to take an action which may harm them",
"When companies or individuals send out emails to promote or sell their products",
"When someone you know sends an email that was forwarded to you encouraging you to forward that message on to everyone in your address book",
"When someone sends an email to a large group of people and one of the recipients replies with a personal response to all recipients of the original email",
"I don’t know"], "Q11" : ['An additional piece of information beyond username and password which someone must provide to gain access to a system (e.g., website)',
"The Frequent changing of a passwords so it is harder for an attacker to guess",
"Adding different numbers to the ends of a usernames so a user never has the same username on multiple sites",
"When someone uses a different password for each web site they access",
"I don’t know"], "Q12" : ["I do not use multifactor authentication.",
"I use multifactor authentication on my important online accounts.",
"I use multifactor authentication on most of my online accounts.",
"I use multifactor authentication wherever it is offered to me.",
"I don’t know."], "Q18" : ["I have never received security awareness training.",
"I have received security awareness training within the past month",
"I have received security awareness training within the past 6 months",
"I have received security awareness training within the past year",
"I have received security awareness training a year or more ago",
"I don’t know."], "Q19" : ["Yes", "No", "I don't know"], "Q20" : ["Yes", "No", "I don't know"], "Q21" : ["Yes", "No", "I don't know"], "Q25" : ["Yes", "No", "I don't know"], "Q26" : ["Yes", "No", "I don't know"], "Q27" : ["Yes", "No", "I don't know"], "Q31" : ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"], "Q29" : ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"], 
        "Q28" : ["Extremely unlikely", "Somewhat unlikely", "Neither likely nor unlikely", "Somewhat likely", "Extremely likely", "I don't know"]}
for i in pairwise_combos:
    if i[1] == 'Q18' and i[0] != 'RandomSurveyID':
        newCrossTab = pd.crosstab(loopData[i[1] + '_x'], loopData[i[0]+'_y'],margins=True, margins_name="Total", normalize="index").rename_axis(index=None, columns=None) * 100
        newCrossTab = newCrossTab.round(2)
        newCrossTab = newCrossTab.astype(str)
        newCrossTab = newCrossTab + " %"
        newCrossTab = newCrossTab.reindex(dict[i[1]], axis="rows")
        newCrossTab = newCrossTab.reindex(dict[i[0]], axis="columns")
        newCrossTab = newCrossTab.style.set_caption("Comparison of " + i[1] + " with " + i[0])
        crosstabs.append(newCrossTab)
    elif i[0] == 'Q18' and i[1] != 'RandomSurveyID':
        newCrossTab = pd.crosstab(loopData[i[0] + '_x'], loopData[i[1]+'_y'],margins=True, margins_name="Total", normalize="index").rename_axis(index=None, columns=None) * 100
        newCrossTab = newCrossTab.round(2)
        newCrossTab = newCrossTab.astype(str)
        newCrossTab = newCrossTab + " %"
        newCrossTab = newCrossTab.reindex(dict[i[0]], axis="rows")
        newCrossTab = newCrossTab.reindex(dict[i[1]], axis="columns")
        newCrossTab = newCrossTab.style.set_caption("Comparison of " + i[0] + " with " + i[1])
        crosstabs.append(newCrossTab)

# %%
from IPython.display import display
for i in range(len(crosstabs)):
    display(crosstabs[i])
# Out:
# <style type="text/css">
# </style>
# <table id="T_611a4">
#   <caption>Comparison of Q18 with Q1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_611a4_level0_col0" class="col_heading level0 col0" >18-24</th>
#       <th id="T_611a4_level0_col1" class="col_heading level0 col1" >25-34</th>
#       <th id="T_611a4_level0_col2" class="col_heading level0 col2" >35-44</th>
#       <th id="T_611a4_level0_col3" class="col_heading level0 col3" >45-54</th>
#       <th id="T_611a4_level0_col4" class="col_heading level0 col4" >55-64</th>
#       <th id="T_611a4_level0_col5" class="col_heading level0 col5" >65 years or older</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_611a4_level0_row0" class="row_heading level0 row0" >I have never received security awareness training.</th>
#       <td id="T_611a4_row0_col0" class="data row0 col0" >12.12 %</td>
#       <td id="T_611a4_row0_col1" class="data row0 col1" >43.18 %</td>
# ...

# %%
myData['Q24'].astype(float).sum()
# Out:
# 436098.95

# %%
from itertools import combinations
regionData = myData.replace(regions, regex=True)
# for now drop all columns that have check all that apply, so crosstabs are done for everything else
regionData = regionData.drop(columns=["ResponseId", "Q5", "Q6", "Q15", "Q16", "Q17", "Q4", "Q24"], axis=1)
loopData = regionData.merge(regionData, on="RandomSurveyID")
pairwise_combos = list(combinations(regionData.columns, 2))
crosstabs = []
dict = {"Q1": ['18-24','25-34','35-44','45-54','55-64','65 years or older'], 
        "Q2": ["Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", 'I don’t know'],
       "Q3": ['Do not have a HS Diploma or GED', 'High School Diploma or GED', 'Associates Degree','Some College', 'Bachelor’s Degree', 'Graduate Degree'], "Q7": ["Within in a week","Within a month","Within a year","More than a year ago","I do not back up my data","I don’t know"],
       "Q8": ["Any action in which someone tries to convince another person to take an action which may not be in their best interests",
"Actively trying to circumvent or get around security safeguards by finding weaknesses in a system that can be exploited without personal interaction",
"Attempting to inform people about the use of proper security policies, processes, and procedures",
"When a company makes a public announcement about something positive that has happened or is going to happen",
"I don’t know"], "Q9": ["When someone fraudulently sends a specifically crafted message to a person to convince them to take an action which may harm them",
"Targeted marketing emails sent to a specific person by a company based on their buying history or web browsing habits",
"When someone sends an email specifically designed to belittle the recipient",
"When someone in a business setting sends an email to a coworker inappropriately delegating their work to the recipient",
"I don’t know"], "Q10" : ["When a someone fraudulently sends email to people to convince them to take an action which may harm them",
"When companies or individuals send out emails to promote or sell their products",
"When someone you know sends an email that was forwarded to you encouraging you to forward that message on to everyone in your address book",
"When someone sends an email to a large group of people and one of the recipients replies with a personal response to all recipients of the original email",
"I don’t know"], "Q11" : ['An additional piece of information beyond username and password which someone must provide to gain access to a system (e.g., website)',
"The Frequent changing of a passwords so it is harder for an attacker to guess",
"Adding different numbers to the ends of a usernames so a user never has the same username on multiple sites",
"When someone uses a different password for each web site they access",
"I don’t know"], "Q12" : ["I do not use multifactor authentication.",
"I use multifactor authentication on my important online accounts.",
"I use multifactor authentication on most of my online accounts.",
"I use multifactor authentication wherever it is offered to me.",
"I don’t know."], "Q18" : ["I have never received security awareness training.",
"I have received security awareness training within the past month",
"I have received security awareness training within the past 6 months",
"I have received security awareness training within the past year",
"I have received security awareness training a year or more ago",
"I don’t know."], "Q19" : ["Yes", "No", "I don't know"], "Q20" : ["Yes", "No", "I don't know"], "Q21" : ["Yes", "No", "I don't know"], "Q25" : ["Yes", "No", "I don't know"], "Q26" : ["Yes", "No", "I don't know"], "Q27" : ["Yes", "No", "I don't know"], "Q31" : ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"], "Q29" : ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"], 
        "Q28" : ["Extremely unlikely", "Somewhat unlikely", "Neither likely nor unlikely", "Somewhat likely", "Extremely likely", "I don't know"]}
for i in pairwise_combos:
    if i[1] == 'Q31' and i[0] != 'RandomSurveyID':
        newCrossTab = pd.crosstab(loopData[i[1] + '_x'], loopData[i[0]+'_y'],margins=True, margins_name="Total", normalize="index").rename_axis(index=None, columns=None) * 100
        newCrossTab = newCrossTab.round(2)
        newCrossTab = newCrossTab.astype(str)
        newCrossTab = newCrossTab + " %"
        newCrossTab = newCrossTab.reindex(dict[i[1]], axis="rows")
        newCrossTab = newCrossTab.reindex(dict[i[0]], axis="columns")
        newCrossTab = newCrossTab.style.set_caption("Comparison of " + i[1] + " with " + i[0])
        crosstabs.append(newCrossTab)
    elif i[0] == 'Q31' and i[1] != 'RandomSurveyID':
        newCrossTab = pd.crosstab(loopData[i[0] + '_x'], loopData[i[1]+'_y'],margins=True, margins_name="Total", normalize="index").rename_axis(index=None, columns=None) * 100
        newCrossTab = newCrossTab.round(2)
        newCrossTab = newCrossTab.astype(str)
        newCrossTab = newCrossTab + " %"
        newCrossTab = newCrossTab.reindex(dict[i[0]], axis="rows")
        newCrossTab = newCrossTab.reindex(dict[i[1]], axis="columns")
        newCrossTab = newCrossTab.style.set_caption("Comparison of " + i[0] + " with " + i[1])
        crosstabs.append(newCrossTab)

# %%
# from IPython.display import display
# for i in range(len(crosstabs)):
#     display(crosstabs[i])

# %%
Q8_answers = {"Any action in which someone tries to convince another person to take an action which may not be in their best interests": 1,
"Actively trying to circumvent or get around security safeguards by finding weaknesses in a system that can be exploited without personal interaction": 0,
"Attempting to inform people about the use of proper security policies, processes, and procedures": 0,
"When a company makes a public announcement about something positive that has happened or is going to happen": 0,
"I don’t know": 0}

myData["Q8"].fillna("I don't know")
myData2["Q8"] = 0
for key, weight in Q8_answers.items():
    myData2.loc[myData['Q8'] == key, 'Q8'] = weight

Q9_answers={"When someone fraudulently sends a specifically crafted message to a person to convince them to take an action which may harm them": 1,
"Targeted marketing emails sent to a specific person by a company based on their buying history or web browsing habits": 0,
"When someone sends an email specifically designed to belittle the recipient": 0,
"When someone in a business setting sends an email to a coworker inappropriately delegating their work to the recipient": 0,
"I don’t know": 0}

myData["Q9"].fillna("I don't know")
myData2["Q9"] = 0
for key, weight in Q9_answers.items():
    myData2.loc[myData['Q9'] == key, 'Q9'] = weight

Q10_answers={"When a someone fraudulently sends email to people to convince them to take an action which may harm them":1,
"When companies or individuals send out emails to promote or sell their products":0,
"When someone you know sends an email that was forwarded to you encouraging you to forward that message on to everyone in your address book":0,
"When someone sends an email to a large group of people and one of the recipients replies with a personal response to all recipients of the original email":0,
"I don’t know":0}


myData["Q10"].fillna("I don't know")
myData2["Q10"] = 0
for key, weight in Q10_answers.items():
    myData2.loc[myData['Q10'] == key, 'Q10'] = weight

Q11_answers={"An additional piece of information beyond username and password which someone must provide to gain access to a system (e.g., website)":1,
"The Frequent changing of a passwords so it is harder for an attacker to guess":0,
"Adding different numbers to the ends of a usernames so a user never has the same username on multiple sites":0,
"When someone uses a different password for each web site they access":0,
"I don’t know":0}
# how to weight them?


myData["Q11"].fillna("I don't know")
myData2["Q11"] = 0
for key, weight in Q11_answers.items():
    myData2.loc[myData['Q11'] == key, 'Q11'] = weight
    
myData2["SecuritySum"] = myData2['Q8'].apply(int) + myData2['Q9'].apply(int) + myData2['Q10'].apply(int) + myData2['Q11'].apply(int)
# myData2 = myData2.drop(['Q8', 'Q9', 'Q10', 'Q11'], axis=1)

# %%
myData2['SecuritySum'].sum()
# Out:
# 1135

# %%
dataToPlot = myData2.groupby('SecuritySum').RandomSurveyID.count()
ax = dataToPlot.plot.bar(rot=90)

plt.ylabel("Number of Participants")
plt.title("Number of Security Awareness Questions Correct")
plt.xlabel("Number 0-4 out of 4 Questions")

heightlst = []
for i in ax.patches:
    heightlst.append(i.get_height())
total = sum(heightlst)

for i in ax.patches:
    height = i.get_height()
    value = ("{0:.2f}".format((i.get_height()/total)*100)+'%')
    ax.annotate(value, (i.get_x() + i.get_width()/2, height+0.05), ha='center', va='bottom')

plt.savefig("SecuritySum.png", bbox_inches="tight")
plt.show()

# %%
myData["SecuritySum"] = myData2['Q8'].apply(int) + myData2['Q9'].apply(int) + myData2['Q10'].apply(int) + myData2['Q11'].apply(int)
securitysum_column = myData['SecuritySum']
myData = myData.drop(columns=['SecuritySum'])
myData.insert(0, 'SecuritySum', securitysum_column)
from itertools import combinations

regionData = myData.replace(regions, regex=True)
# for now drop all columns that have check all that apply, so crosstabs are done for everything else
regionData = regionData.drop(columns=["ResponseId", "Q5", "Q6", "Q15", "Q16", "Q17", "Q4", "Q24"], axis=1)
loopData = regionData.merge(regionData, on="RandomSurveyID")
pairwise_combos = list(combinations(regionData.columns, 2))
crosstabs = []
dict = {"Q1": ['18-24','25-34','35-44','45-54','55-64','65 years or older'], 
        "Q2": ["Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", 'I don’t know'],
       "Q3": ['Do not have a HS Diploma or GED', 'High School Diploma or GED', 'Associates Degree','Some College', 'Bachelor’s Degree', 'Graduate Degree'], "Q7": ["Within in a week","Within a month","Within a year","More than a year ago","I do not back up my data","I don’t know"],
       "Q8": ["Any action in which someone tries to convince another person to take an action which may not be in their best interests",
"Actively trying to circumvent or get around security safeguards by finding weaknesses in a system that can be exploited without personal interaction",
"Attempting to inform people about the use of proper security policies, processes, and procedures",
"When a company makes a public announcement about something positive that has happened or is going to happen",
"I don’t know"], "Q9": ["When someone fraudulently sends a specifically crafted message to a person to convince them to take an action which may harm them",
"Targeted marketing emails sent to a specific person by a company based on their buying history or web browsing habits",
"When someone sends an email specifically designed to belittle the recipient",
"When someone in a business setting sends an email to a coworker inappropriately delegating their work to the recipient",
"I don’t know"], "Q10" : ["When a someone fraudulently sends email to people to convince them to take an action which may harm them",
"When companies or individuals send out emails to promote or sell their products",
"When someone you know sends an email that was forwarded to you encouraging you to forward that message on to everyone in your address book",
"When someone sends an email to a large group of people and one of the recipients replies with a personal response to all recipients of the original email",
"I don’t know"], "Q11" : ['An additional piece of information beyond username and password which someone must provide to gain access to a system (e.g., website)',
"The Frequent changing of a passwords so it is harder for an attacker to guess",
"Adding different numbers to the ends of a usernames so a user never has the same username on multiple sites",
"When someone uses a different password for each web site they access",
"I don’t know"], "Q12" : ["I do not use multifactor authentication.",
"I use multifactor authentication on my important online accounts.",
"I use multifactor authentication on most of my online accounts.",
"I use multifactor authentication wherever it is offered to me.",
"I don’t know."], "Q18" : ["I have never received security awareness training.",
"I have received security awareness training within the past month",
"I have received security awareness training within the past 6 months",
"I have received security awareness training within the past year",
"I have received security awareness training a year or more ago",
"I don’t know."], "Q19" : ["Yes", "No", "I don't know"], "Q20" : ["Yes", "No", "I don't know"], "Q21" : ["Yes", "No", "I don't know"], "Q25" : ["Yes", "No", "I don't know"], "Q26" : ["Yes", "No", "I don't know"], "Q27" : ["Yes", "No", "I don't know"], "Q31" : ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"], "Q29" : ["Strongly disagree", "Somewhat disagree", "Neither agree nor disagree", "Somewhat agree", "Strongly agree"],
        "Q28" : ["Extremely unlikely", "Somewhat unlikely", "Neither likely nor unlikely", "Somewhat likely", "Extremely likely", "I don't know"], "SecuritySum": [0, 1, 2, 3, 4]}
for i in pairwise_combos:
    if i[1] == 'SecuritySum' and i[0] != 'RandomSurveyID':
        newCrossTab = pd.crosstab(loopData[i[0]+'_y'],loopData[i[1] + '_x'], margins=True, margins_name="Total", normalize="index").rename_axis(index=None, columns=None) * 100
        newCrossTab = newCrossTab.round(2)
        newCrossTab = newCrossTab.astype(str)
        newCrossTab = newCrossTab + " %"
        newCrossTab = newCrossTab.reindex(dict[i[1]], axis="columns")
        newCrossTab = newCrossTab.reindex(dict[i[0]], axis="rows")
        newCrossTab = newCrossTab.style.set_caption("Comparison of " + i[0] + " with " + i[1])
        crosstabs.append(newCrossTab)
    elif i[0] == 'SecuritySum' and i[1] != 'RandomSurveyID':
        newCrossTab = pd.crosstab(loopData[i[1]+'_y'],loopData[i[0] + '_x'],margins=True, margins_name="Total", normalize="index").rename_axis(index=None, columns=None) * 100
        newCrossTab = newCrossTab.round(2)
        newCrossTab = newCrossTab.astype(str)
        newCrossTab = newCrossTab + " %"
        newCrossTab = newCrossTab.reindex(dict[i[0]], axis="columns")
        newCrossTab = newCrossTab.reindex(dict[i[1]], axis="rows")
        newCrossTab = newCrossTab.style.set_caption("Comparison of " + i[1] + " with " + i[0])
        crosstabs.append(newCrossTab)

from IPython.display import display
for i in range(len(crosstabs)):
    display(crosstabs[i])
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba44d">
#   <caption>Comparison of Q1 with SecuritySum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba44d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T
    "73.87.134.207",
    "68.33.15.250",
    "73.191.3.106",
    "71.200.91.122",
    "76.151.56.228",
    "98.204.24.153",
    "38.134.123.29",
    "68.83.222.121",
    "109.94.216.130",
    "68.33.198.84",
    "149.46.192.126",
    "149.46.193.131",
    "149.46.192.84",
    "73.173.229.102",
    "208.218.230.197",
    "208.218.229.9",
    "50.236.164.72",
    "68.134.57.220",
    "174.192.207.209",
    "208.200.1.32",
    "208.200.1.98",
    "108.31.184.153",
    "173.66.177.252",
    "208.200.2.96",
    "69.243.85.68",
    "209.107.190.145",
    "173.73.50.132",
    "69.143.26.134",
    "69.2.165.35",
    "108.40.127.133",
    "100.18.10.68",
    "173.175.227.165",
    "64.98.245.142",
    "38.70.11.121",
    "75.194.215.30",
    "216.73.161.81",
    "67.166.181.251",
    "76.106.35.201",
    "172.58.188.189",
    "154.16.106.125",
    "69.250.79.28",
    "73.78.65.218",
    "157.49.246.193",
    "96.241.181.200",
    "43.246.136.11",
    "165.140.166.15",
    "71.163.24.234",
    "129.2.181.87",
    "174.231.208.209",
    "72.81.246.226",
    "185.235.120.231",
    "185.186.62.122",
    "79.106.204.17",
    "100.15.133.170",
    "72.49.20.146",
    "73.133.18.100",
    "98.233.249.55",
    "174.172.40.196",
    "172.58.158.150",
    "129.222.219.164",
    "38.140.210.50",
    "130.85.59.148",
    "100.16.157.189",
]

def is_ip_in_us(ip, max_retries=5):
    for retry in range(max_retries):
        try:
            obj = ipwhois.IPWhois(ip)
            results = obj.lookup_rdap()
            country = results.get('asn_country_code')
            return country == "US"
        except ipwhois.exceptions.IPDefinedError:
            return False
        except Exception as e:
            if retry == max_retries - 1:
                print(f"Error for {ip}: {e}")
    return False

def are_coordinates_in_us(latitude, longitude):
    location = geolocator.reverse((latitude, longitude), exactly_one=True)
    return 'United States' in location.address

# Check IP addresses
for ip in ip_addresses:
    full_ip = f"{ip}.1"

    if is_ip_in_us(ip):
        print(f"{ip} is in the United States")
    else:
        print(f"{ip} is NOT in the United States")


geolocator.close()

# %%
myData
# Out:
#      SecuritySum         ResponseId     Q1                   Q2  \
# 2              3  R_2CqUd9CXCG0tzGD  25-34       Baltimore City
# 3              0  R_3EGstGM2YVAsvp6  55-64    St. Mary's County
# 4              2  R_2R52aDdvzDLKmXJ  25-34         I don’t know
# 5              0  R_2djdShi2f5RLxdK  25-34      Allegany County
# 6              3  R_1dFdiUBHkKjZ0R3  18-24    Washington County
# ..           ...                ...    ...                  ...
# 546            4  R_3kvrfhQbyHq4Bqi  25-34       Baltimore City
# 547            3  R_3jcjZzHqFU3vqJY  45-54      Somerset County
# 548            2  R_3qVvdBYb4iFZwoc  35-44    Montgomery County
# 549            3  R_ZLa2ur5dBypwQeZ  18-24     Baltimore County
# 550            3  R_Q0SygZrbGISzAWt  25-34  Anne Arundel County
#
#                     Q3    Q4  \
# 2      Graduate Degree  1988
# 3    Bachelor’s Degree  1960
# 4    Bachelor’s Degree  1990
# 5    Bachelor’s Degree  1995
# 6    Bachelor’s Degree  2001
# ...
