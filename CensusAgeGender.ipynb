# %%
import pandas as pd 
import json
import numpy as np
import matplotlib.pyplot as plt

myData = pd.read_csv("Results314Edited.csv")

myData = myData.drop([0,1])

myData2 = myData.copy(deep=True)

Q8_answers = {"Any action in which someone tries to convince another person to take an action which may not be in their best interests": 1,
"Actively trying to circumvent or get around security safeguards by finding weaknesses in a system that can be exploited without personal interaction": 0,
"Attempting to inform people about the use of proper security policies, processes, and procedures": 0,
"When a company makes a public announcement about something positive that has happened or is going to happen": 0,
"I don’t know": 0}

myData["Q8"].fillna("I don't know")
myData2["Q8"] = 0
for key in Q8_answers.keys():
    myData2.loc[myData['Q8'].str.contains(key, na=False), 'Q8'] = Q8_answers[key]

Q9_answers={"When someone fraudulently sends a specifically crafted message to a person to convince them to take an action which may harm them": 1,
"Targeted marketing emails sent to a specific person by a company based on their buying history or web browsing habits": 0,
"When someone sends an email specifically designed to belittle the recipient": 0,
"When someone in a business setting sends an email to a coworker inappropriately delegating their work to the recipient": 0,
"I don’t know": 0}

myData["Q9"].fillna("I don't know")
myData2["Q9"] = 0
for key in Q9_answers.keys():
    myData2.loc[myData['Q9'].str.contains(key, na=False), 'Q9'] = Q9_answers[key]

Q10_answers={"When a someone fraudulently sends email to people to convince them to take an action which may harm them":1,
"When companies or individuals send out emails to promote or sell their products":0,
"When someone you know sends an email that was forwarded to you encouraging you to forward that message on to everyone in your address book":0,
"When someone sends an email to a large group of people and one of the recipients replies with a personal response to all recipients of the original email":0,
"I don’t know":0}


myData["Q10"].fillna("I don't know")
myData2["A10"] = 0
for key in Q10_answers.keys():
    myData2.loc[myData['Q10'].str.contains(key, na=False), 'Q10'] = Q10_answers[key]

Q11_answers={'An additional piece of information beyond username and password which someone must provide to gain access to a system (e.g., website)':1,
"The Frequent changing of a passwords so it is harder for an attacker to guess":0,
"Adding different numbers to the ends of a usernames so a user never has the same username on multiple sites":0,
"When someone uses a different password for each web site they access":0,
"I don’t know":0}
# how to weight them?


myData["Q11"].fillna("I don't know")
myData2["Q11"] = 0
for key in Q11_answers.keys():
    myData2.loc[myData['Q11'].str.contains(key, na=False), 'Q11'] = Q11_answers[key]
    myData2['Q11'] = myData2['Q11'].replace(key, Q11_answers[key])

Q12_answers={"I do not use multifactor authentication.":1,
"I use multifactor authentication on my important online accounts.":2,
"I use multifactor authentication on most of my online accounts.":3,
"I use multifactor authentication wherever it is offered to me.":4,
"I don’t know.":0}


myData["Q12"].fillna("I don't know")
myData2["Q12"] = 0
for key in Q12_answers.keys():
    myData2.loc[myData['Q12'].str.contains(key, na=False), 'Q12'] += Q12_answers[key]

Q15_answers={"I do not use multifactor authentication":1,
"Messages sent to my phone that contain a code":2,
"An application on my phone that verifies I am logging in":2,
"An application that generates a one-time code":2,
"A hardware security token (e.g., YubiKey or Google Titan)":2,
"I don’t know.":0}

myData["Q15"].fillna("I don't know")
sQ15 = myData['Q15'].str.split(';').explode().value_counts().to_frame('Count')
myData2["Q15"] = 0
for key in Q15_answers.keys():
    myData2.loc[myData['Q15'].str.contains(key, na=False), 'Q15'] += Q15_answers[key]

Q16_answers={"I use the same password for all of my accounts":1,
"I use the same password for most of my accounts":2,
"I use passwords that are similar but different for all of my accounts":3,
"I use personal information (names of pets, children, or friends) as all or part of my password":4,
"I use a unique complex password for my accounts":5,
"I don’t know.":0}

myData["Q16"].fillna("I don't know")
sQ16 = myData['Q16'].str.split(';').explode().value_counts().to_frame('Count')
myData2["Q16"] = 0
for key in Q16_answers.keys():
    myData2.loc[myData['Q16'].str.contains(key, na=False), 'Q16'] += Q16_answers[key]

Q17_answers={"I remember my passwords":1,
"I write my passwords down":2,
"I use a password manager":3,
"I don’t know":0}


myData["Q17"].fillna("I don't know")
sQ17 = myData['Q17'].str.split(';').explode().value_counts().to_frame('Count')
myData2["Q17"] = 0
for key in Q17_answers.keys():
    myData2.loc[myData['Q17'].str.contains(key, na=False), 'Q17'] += Q17_answers[key]

Q18_answers={"I have never received security awareness training.":1,
"I have received security awareness training within the past month":5,
"I have received security awareness training within the past 6 months":4,
"I have received security awareness training within the past year":3,
"I have received security awareness training a year or more ago":2,
"I don’t know.":0}


myData["Q18"].fillna("I don't know")
myData2["Q18"] = 0
for key in Q18_answers.keys():
    myData2.loc[myData['Q18'].str.contains(key, na=False), 'Q18'] = Q18_answers[key]

History_answers = {"Yes":2, "No":1,"I don't know":0}

myData["Q19"].fillna("I don't know")
myData2["Q19"] = 0
for key in History_answers.keys():
    myData2.loc[myData['Q19'].str.contains(key, na=False), 'Q19'] = History_answers[key]

myData["Q20"].fillna("I don't know")
myData2["Q20"] = 0
for key in History_answers.keys():
    myData2.loc[myData['Q20'].str.contains(key, na=False), 'Q20'] = History_answers[key]

myData["Q21"].fillna("I don't know")
myData2["Q21"] = 0
for key in History_answers.keys():
    myData2.loc[myData['Q21'].str.contains(key, na=False), 'Q21'] = History_answers[key]

myData["Q25"].fillna("I don't know")
myData2["Q25"] = 0
for key in History_answers.keys():
    myData2.loc[myData['Q25'].str.contains(key, na=False), 'Q25'] = History_answers[key]

myData["Q26"].fillna("I don't know")
myData2["Q26"] = 0
for key in History_answers.keys():
    myData2.loc[myData['Q26'].str.contains(key, na=False), 'Q26'] = History_answers[key]

myData["Q27"].fillna("I don't know")
myData2["Q27"] = 0
for key in History_answers.keys():
    myData2.loc[myData['Q27'].str.contains(key, na=False), 'Q27'] = History_answers[key]

Scale_agree_answers={"Strongly disagree":0, "Somewhat disagree":1, "Neither agree nor disagree":2, "Somewhat agree":3, "Strongly agree":4}
Scale_likely_answers = {"Extremely unlikely":5, "Somewhat unlikely":4, "Neither likely nor unlikely":3, "Somewhat likely":2, "Extremely likely":1, "I don't know":0}

myData["Q28"].fillna("I don't know")
myData2["Q28"] = 0
for key in Scale_likely_answers.keys():
    myData2.loc[myData['Q28'].str.contains(key, na=False), 'Q28'] = Scale_likely_answers[key]

myData["Q29"].fillna("Neither agree nor disagree")
myData2["Q29"] = 0
for key in Scale_agree_answers.keys():
    myData2.loc[myData['Q29'].str.contains(key, na=False), 'Q29'] = Scale_agree_answers[key]

myData["Q31"].fillna("Neither agree nor disagree")
myData2["Q31"] = 0
for key in Scale_agree_answers.keys():
    myData2.loc[myData['Q31'].str.contains(key, na=False), 'Q31'] = Scale_agree_answers[key]

Q5_answers = {"I use a cloud service (e.g., Microsoft OneDrive, Carbonite, Google Drive)":5,
"I use removable storage that I keep in my house":4,
"I use removable storage that I keep in a location other than my house":3,
"I use keep multiple copies of my files on my computer":2,
"I do not back up my data":1,
"I don’t know}":0}

myData["Q5"].fillna("I don't know")
sQ5 = myData['Q5'].str.split(';').explode().value_counts().to_frame('Count')
myData2["Q5"] = 0
for key in Q5_answers.keys():
    myData2.loc[myData['Q5'].str.contains(key, na=False), 'Q5'] += Q5_answers[key]

Q6_answers = {"Continuously":7,
"Daily":6,
"Weekly":5,
"Monthly":4,
"Less often than monthly but at least once a year":3,
"Once a year or less frequently":2,
"I do not back up my data":1,
"I don’t know":0}


myData["Q6"].fillna("I don't know")
sQ6 = myData['Q6'].str.split(';').explode().value_counts().to_frame('Count')
myData2["Q6"] = 0
for key in Q6_answers.keys():
    myData2.loc[myData['Q6'].str.contains(key, na=False), 'Q6'] += Q6_answers[key]

Q7_answers = {"Within a day":6,
"Within in a week":5,
"Within a month":4,
"Within a year":3,
"More than a year ago":2,
"I do not back up my data":1,
"I don’t know":0}


myData["Q7"].fillna("I don't know")
myData2["Q7"] = 0
for key in Q7_answers.keys():
    myData2.loc[myData['Q7'].str.contains(key, na=False), 'Q7'] = Q7_answers[key]
    
myData = myData.replace('65-75', '65 years or older').replace("75 years or older", "65 years or older")

censusData = pd.read_csv("AgeComparisons.csv")

censusData["AGE1824"] = censusData['AGE1824_TOT'].apply(int)
censusData["AGE2534"] = censusData['AGE2529_TOT'].apply(int) + censusData['AGE3034_TOT'].apply(int)
censusData["AGE3544"] = censusData['AGE3539_TOT'].apply(int) + censusData['AGE4044_TOT'].apply(int)
censusData["AGE4554"] = censusData['AGE4549_TOT'].apply(int) + censusData['AGE5054_TOT'].apply(int)
censusData["AGE5564"] = censusData['AGE5559_TOT'].apply(int) + censusData['AGE6064_TOT'].apply(int)
censusData["AGE6574"] = censusData['AGE6569_TOT'].apply(int) + censusData['AGE7074_TOT'].apply(int)
censusData["AGE75OVER"] = censusData['AGE7579_TOT'].apply(int) + censusData['AGE8084_TOT'].apply(int) + censusData['AGE85PLUS_TOT'].apply(int)
censusData["AGE65+"] = censusData.AGE6574 + censusData.AGE75OVER
censusData = censusData.drop(columns = ["AGE6574", "AGE75OVER"])

censusData = censusData.drop(columns=['SUMLEV', 'STATE', 'COUNTY', 'STNAME', 'YEAR',
       'POPEST_MALE', 'POPEST_FEM', 'UNDER5_TOT', 'UNDER5_MALE', 'UNDER5_FEM',
       'AGE513_TOT', 'AGE513_MALE', 'AGE513_FEM', 'AGE1417_TOT',
       'AGE1417_MALE', 'AGE1417_FEM', 'AGE1824_TOT', 'AGE1824_MALE',
       'AGE1824_FEM', 'AGE16PLUS_TOT', 'AGE16PLUS_MALE', 'AGE16PLUS_FEM',
       'AGE18PLUS_TOT', 'AGE18PLUS_MALE', 'AGE18PLUS_FEM', 'AGE1544_TOT',
       'AGE1544_MALE', 'AGE1544_FEM', 'AGE2544_TOT', 'AGE2544_MALE',
       'AGE2544_FEM', 'AGE4564_TOT', 'AGE4564_MALE', 'AGE4564_FEM',
       'AGE65PLUS_TOT', 'AGE65PLUS_MALE', 'AGE65PLUS_FEM', 'AGE04_TOT',
       'AGE04_MALE', 'AGE04_FEM', 'AGE59_TOT', 'AGE59_MALE', 'AGE59_FEM',
       'AGE1014_TOT', 'AGE1014_MALE', 'AGE1014_FEM', 'AGE1519_TOT',
       'AGE1519_MALE', 'AGE1519_FEM', 'AGE2024_TOT', 'AGE2024_MALE',
       'AGE2024_FEM', 'AGE2529_TOT', 'AGE2529_MALE', 'AGE2529_FEM',
       'AGE3034_TOT', 'AGE3034_MALE', 'AGE3034_FEM', 'AGE3539_TOT',
       'AGE3539_MALE', 'AGE3539_FEM', 'AGE4044_TOT', 'AGE4044_MALE',
       'AGE4044_FEM', 'AGE4549_TOT', 'AGE4549_MALE', 'AGE4549_FEM',
       'AGE5054_TOT', 'AGE5054_MALE', 'AGE5054_FEM', 'AGE5559_TOT',
       'AGE5559_MALE', 'AGE5559_FEM', 'AGE6064_TOT', 'AGE6064_MALE',
       'AGE6064_FEM', 'AGE6569_TOT', 'AGE6569_MALE', 'AGE6569_FEM',
       'AGE7074_TOT', 'AGE7074_MALE', 'AGE7074_FEM', 'AGE7579_TOT',
       'AGE7579_MALE', 'AGE7579_FEM', 'AGE8084_TOT', 'AGE8084_MALE',
       'AGE8084_FEM', 'AGE85PLUS_TOT', 'AGE85PLUS_MALE', 'AGE85PLUS_FEM',
       'MEDIAN_AGE_MALE', 'MEDIAN_AGE_FEM' ,'MEDIAN_AGE_TOT'])

censusData.replace({"Baltimore city": "Baltimore City"}, inplace=True)
censusData = censusData.iloc[::3].reset_index()

regions = {"Frederick County":"Capital Region", "Montgomery County":"Capital Region", "Prince George's County":"Capital Region", 
        "Anne Arundel County":"Central Maryland", "Baltimore City":"Central Maryland", "Baltimore County":"Central Maryland", "Carroll County":"Central Maryland", "Cecil County":"Central Maryland", "Harford County":"Central Maryland", "Howard County":"Central Maryland", 
        "Caroline County":"Eastern Shore of Maryland", "Dorchester County":"Eastern Shore of Maryland", "Kent County":"Eastern Shore of Maryland", "Queen Anne's County":"Eastern Shore of Maryland", "Somerset County":"Eastern Shore of Maryland", "Talbot County":"Eastern Shore of Maryland", "Wicomico County":"Eastern Shore of Maryland", "Worcester County":"Eastern Shore of Maryland",
        "Calvert County":"Southern Maryland", "Charles County":"Southern Maryland", "St. Mary's County":"Southern Maryland",
        "Allegany County":"Western Maryland", "Garrett County":"Western Maryland", "Washington County":"Western Maryland"}
regionData = censusData.replace(regions, regex=True)
myRegionData = myData.replace(regions, regex=True)
# Out:
# /var/folders/5r/_p7z4vjd0djbm7rn2zqdjblc0000gn/T/ipykernel_3699/4111857144.py:57: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   myData2.loc[myData['Q11'].str.contains(key, na=False), 'Q11'] = Q11_answers[key]
# /var/folders/5r/_p7z4vjd0djbm7rn2zqdjblc0000gn/T/ipykernel_3699/4111857144.py:83: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   myData2.loc[myData['Q15'].str.contains(key, na=False), 'Q15'] += Q15_answers[key]
# /var/folders/5r/_p7z4vjd0djbm7rn2zqdjblc0000gn/T/ipykernel_3699/4111857144.py:96: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   myData2.loc[myData['Q16'].str.contains(key, na=False), 'Q16'] += Q16_answers[key]
# /var/folders/5r/_p7z4vjd0djbm7rn2zqdjblc0000gn/T/ipykernel_3699/4111857144.py:184: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   myData2.loc[myData['Q5'].str.contains(key, na=False), 'Q5'] += Q5_answers[key]

# %%
censusDataFlop = censusData.replace(regions, regex=True)
censusDataFlop = censusDataFlop.groupby("CTYNAME").sum()
censusDataFlop = censusDataFlop.transpose()
censusDataFlop = censusDataFlop.drop(index=['index'])
censusDataFlop["Total"] = censusDataFlop.sum(axis=1)
censusDataFlop = censusDataFlop.rename(index={"AGE1824":"18-24", "AGE2534":"25-34","AGE3544":"35-44","AGE4554":"45-54","AGE5564":"55-64", "AGE65+": "65 years or older"})

# %%
myRegionDataTotal = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

regionDataTotal = regionData.rename(columns={"POPESTIMATE": "Census_Data"})
grouped = regionDataTotal.groupby("CTYNAME").Census_Data.sum()
grouped["I don’t know"] = 0

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("Jurisdiction of Primary Residence\n for All Maryland Residents")
ax2 = ax.twinx()
width = 0.4

x_order = [ "Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", "I don’t know"]
grouped.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionDataTotal.groupby("Q2").Survey_Data.count().loc[x_order].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Region")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyTotalAgePerRegion.png", bbox_inches="tight")
plt.show()
# make the axes percents
# make both
# more mturk workers in western maryland?

# %%
myRegionData18 = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

regionData18 = regionData.rename(columns={"AGE1824": "Census_Data"})
grouped = regionData18.groupby("CTYNAME").Census_Data.sum()
grouped["I don’t know"] = 0

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("18-24 Year Olds In Maryland Regions")
ax2 = ax.twinx()
width = 0.4

x_order = [ "Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", "I don’t know"]
grouped.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionData18 = myRegionData18[myRegionData18.Q1 == "18-24"]
myRegionData18.groupby("Q2").Survey_Data.count().loc[x_order].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Region")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyAge18-24PerRegion.png", bbox_inches="tight")
plt.show()

# %%
myRegionData25 = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

regionData25 = regionData.rename(columns={"AGE2534": "Census_Data"})
grouped = regionData25.groupby("CTYNAME").Census_Data.sum()
grouped["I don’t know"] = 0

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("25-34 Year Olds In Maryland Regions")
ax2 = ax.twinx()
width = 0.4

x_order = [ "Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", "I don’t know"]
grouped.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionData25 = myRegionData25[myRegionData25.Q1 == "25-34"]
myRegionData25.groupby("Q2").Survey_Data.count().loc[x_order].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Region")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyAge25-34PerRegion.png", bbox_inches="tight")
plt.show()

# %%
myRegionData35 = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

regionData35 = regionData.rename(columns={"AGE3544": "Census_Data"})
grouped = regionData35.groupby("CTYNAME").Census_Data.sum()
grouped["I don’t know"] = 0

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("35-44 Year Olds In Maryland Regions")
ax2 = ax.twinx()
width = 0.4

x_order = [ "Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", "I don’t know"]
grouped.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionData35 = myRegionData35[myRegionData35.Q1 == "35-44"]
myRegionData35.groupby("Q2").Survey_Data.count().loc[x_order].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Region")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyAge35-44PerRegion.png", bbox_inches="tight")
plt.show()

# %%
myRegionData45 = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

regionData45 = regionData.rename(columns={"AGE4554": "Census_Data"})
grouped = regionData45.groupby("CTYNAME").Census_Data.sum()
grouped["I don’t know"] = 0

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("45-54 Year Olds In Maryland Regions")
ax2 = ax.twinx()
width = 0.4

x_order = [ "Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", "I don’t know"]
grouped.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionData45 = myRegionData45[myRegionData45.Q1 == "45-54"]
myRegionData45.groupby("Q2").Survey_Data.count().loc[x_order].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Region")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyAge45-54PerRegion.png", bbox_inches="tight")
plt.show()

# %%
myRegionData55 = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

regionData55 = regionData.rename(columns={"AGE5564": "Census_Data"})
grouped = regionData55.groupby("CTYNAME").Census_Data.sum()
grouped["I don’t know"] = 0

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("55-64 Year Olds In Maryland Regions")
ax2 = ax.twinx()
width = 0.4

x_order = [ "Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", "I don’t know"]
grouped.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionData55 = myRegionData55[myRegionData55.Q1 == "55-64"]
myRegionData55.groupby("Q2").Survey_Data.count().loc[x_order].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Region")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyAge55-64PerRegion.png", bbox_inches="tight")
plt.show()

# %%
myRegionData65 = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

regionData65 = regionData.rename(columns={"AGE65+": "Census_Data"})
grouped = regionData65.groupby("CTYNAME").Census_Data.sum()
grouped["I don’t know"] = 0

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("65+ Year Olds In Maryland Regions")
ax2 = ax.twinx()
width = 0.4

x_order = [ "Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", "I don’t know"]
grouped.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionData56 = myRegionData65[myRegionData65.Q1 == "65 years or older"]
myRegionData65.groupby("Q2").Survey_Data.count().loc[x_order].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Region")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyAge65+PerRegion.png", bbox_inches="tight")
plt.show()

# %%
myRegionDataTotal = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

regionDataTotal = regionData.rename(columns={"POPESTIMATE": "Census_Data"})
grouped = regionDataTotal.groupby("CTYNAME").Census_Data.sum()
grouped["I don’t know"] = 0

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("Jurisdiction of Primary Residence\n for All Maryland Residents")
ax2 = ax.twinx()
width = 0.4

x_order = [ "Capital Region", "Central Maryland", "Eastern Shore of Maryland", "Southern Maryland", "Western Maryland", "I don’t know"]
grouped.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionDataTotal.groupby("Q2").Survey_Data.count().loc[x_order].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Region")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyTotalAgePerRegion.png", bbox_inches="tight")
plt.show()
# make the axes percents
# make both
# more mturk workers in western maryland?

# %%
censusDataFlop
# Out:
# CTYNAME            Capital Region  Central Maryland  \
# POPESTIMATE               2300979           2898361
# 18-24                      193839            245964
# 25-34                      302763            410068
# 35-44                      316102            381650
# 45-54                      311990            365636
# 55-64                      306348            396330
# 65 years or older          342467            458294
#
# CTYNAME            Eastern Shore of Maryland  Southern Maryland  \
# POPESTIMATE                           353090             373177
# 18-24                                  35537              31617
# 25-34                                  39996              47882
# 35-44                                  37898              48252
# 45-54                                  42066              52364
# 55-64                                  51968              52976
# 65 years or older                      73977              50846
#
# CTYNAME            Western Maryland    Total
# POPESTIMATE                  251617  6177224
# 18-24                         22638   529595
# 25-34                         31874   832583
# 35-44                         30468   814370
# 45-54                         33101   805157
# 55-64                         35201   842823
# 65 years or older             47174   972758

# %%
myRegionDataTotal = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

grouped = censusDataFlop.rename(columns={"Total": "Census_Data"})

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("Age Group for All Maryland Residents")
ax2 = ax.twinx()
width = 0.4

x_order = [ "18-24", "25-34", "35-44", "45-54", "55-64", "65 years or older"]
grouped.Census_Data.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionDataTotal.groupby("Q1").Survey_Data.count().plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Age Groups")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyTotalAgePerState.png", bbox_inches="tight")
plt.show()

# %%
censusDataFlop
# Out:
# CTYNAME            Capital Region  Central Maryland  \
# POPESTIMATE               2300979           2898361
# 18-24                      193839            245964
# 25-34                      302763            410068
# 35-44                      316102            381650
# 45-54                      311990            365636
# 55-64                      306348            396330
# 65 years or older          342467            458294
#
# CTYNAME            Eastern Shore of Maryland  Southern Maryland  \
# POPESTIMATE                           353090             373177
# 18-24                                  35537              31617
# 25-34                                  39996              47882
# 35-44                                  37898              48252
# 45-54                                  42066              52364
# 55-64                                  51968              52976
# 65 years or older                      73977              50846
#
# CTYNAME            Western Maryland    Total
# POPESTIMATE                  251617  6177224
# 18-24                         22638   529595
# 25-34                         31874   832583
# 35-44                         30468   814370
# 45-54                         33101   805157
# 55-64                         35201   842823
# 65 years or older             47174   972758

# %%
myRegionDataTotal = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

grouped = censusDataFlop.rename(columns={"Capital Region": "Census_Data"})

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("Age Group for All Capital Region Residents")
ax2 = ax.twinx()
width = 0.4

x_order = [ "18-24", "25-34", "35-44", "45-54", "55-64", "65 years or older"]
grouped.Census_Data.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionDataTotal[myRegionDataTotal.Q2 == "Capital Region"].groupby("Q1").Survey_Data.count().plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Age Groups")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyTotalAgePerCapitalRegion.png", bbox_inches="tight")
plt.show()

# %%
myRegionDataTotal = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

grouped = censusDataFlop.rename(columns={"Central Maryland": "Census_Data"})

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("Age Group for All Central Maryland Residents")
ax2 = ax.twinx()
width = 0.4

x_order = [ "18-24", "25-34", "35-44", "45-54", "55-64", "65 years or older"]
grouped.Census_Data.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionDataTotal[myRegionDataTotal.Q2 == "Central Maryland"].groupby("Q1").Survey_Data.count().plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Age Groups")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyTotalAgePerCentralMaryland.png", bbox_inches="tight")
plt.show()

# %%
myRegionDataTotal = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

grouped = censusDataFlop.rename(columns={"Eastern Shore of Maryland": "Census_Data"})

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("Age Group for All Eastern Shore of Maryland Residents")
ax2 = ax.twinx()
width = 0.4

x_order = [ "18-24", "25-34", "35-44", "45-54", "55-64", "65 years or older"]
grouped.Census_Data.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionDataTotal[myRegionDataTotal.Q2 == "Eastern Shore of Maryland"].groupby("Q1").Survey_Data.count().plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Age Groups")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyTotalAgePerEasternShoreOfMaryland.png", bbox_inches="tight")
plt.show()

# %%
myRegionDataTotal = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

grouped = censusDataFlop.rename(columns={"Southern Maryland": "Census_Data"})

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("Age Group for All Southern Maryland Residents")
ax2 = ax.twinx()
width = 0.4

x_order = [ "18-24", "25-34", "35-44", "45-54", "55-64", "65 years or older"]
grouped.Census_Data.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionDataTotal[myRegionDataTotal.Q2 == "Southern Maryland"].groupby("Q1").Survey_Data.count().plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Age Groups")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyTotalAgePerSouthernMaryland.png", bbox_inches="tight")
plt.show()

# %%
myRegionDataTotal = myRegionData.rename(columns={"RandomSurveyID": "Survey_Data"})

grouped = censusDataFlop.rename(columns={"Western Maryland": "Census_Data"})

fig = plt.figure()
ax = fig.add_subplot(111)
plt.title("Age Group for All Western Maryland Residents")
ax2 = ax.twinx()
width = 0.4

x_order = [ "18-24", "25-34", "35-44", "45-54", "55-64", "65 years or older"]
grouped.Census_Data.loc[x_order].plot(kind='bar', color='red', ax=ax, width=width, position=1)
myRegionDataTotal[myRegionDataTotal.Q2 == "Western Maryland"].groupby("Q1").Survey_Data.count().plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_xlabel("Age Groups")
ax.set_ylabel('Census Data')
ax2.set_ylabel('Survey Data')
plt.xlim(-1, 6)
ax.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.savefig("CensusvsSurveyTotalAgePerWesternMaryland.png", bbox_inches="tight")
plt.show()
