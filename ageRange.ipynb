# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv("Results314Edited.csv")
df = df.drop([0, 1])

# Reset the index to start from 0
df = df.reset_index(drop=True)

# Function to calculate the allowed birth years for the age range
def calculate_allowed_birth_years(age_range):
    # Split the age range by '-'
    if age_range == "75 years or older":
        start_age, end_age = 75, 90
    else:
        start_age, end_age = map(int, age_range.split('-'))

    # Calculate the allowed birth years (assuming the current year is 2023)
    allowed_birth_years = list(range(2023 - end_age, 2023 - start_age + 1))
    
    # Add one less than the smallest allowed birth year
    allowed_birth_years.append(allowed_birth_years[0] - 1)
    
    return allowed_birth_years

# Create a dictionary to store allowed birth years for each age range
allowed_birth_years_dict = {}

# Iterate through the DataFrame and calculate allowed birth years
for index, row in df.iterrows():
    age_range = row["Q1"]
    allowed_birth_years = calculate_allowed_birth_years(age_range)
    
    # Store the allowed birth years in the dictionary
    allowed_birth_years_dict[age_range] = allowed_birth_years

# Initialize counters for matches, non-matches, and dictionaries to store them
matches = 0
non_matches = 0
matches_dict = {}
non_matches_dict = {}

# Iterate through the DataFrame and check if birth year matches the allowed years for age range
for index, row in df.iterrows():
    age_range = row["Q1"]
    birth_year = int(row["Q4"])
    
    allowed_birth_years = allowed_birth_years_dict.get(age_range, [])
    
    if birth_year in allowed_birth_years:
        matches += 1
        matches_dict[index + 2] = f"Birth year ({birth_year}) matches the expected year for age range {age_range}."
    else:
        non_matches += 1
        closest_year = min(allowed_birth_years, key=lambda x: abs(x - birth_year))
        year_difference = abs(birth_year - closest_year)
        non_matches_dict[index + 2] = f"Birth year ({birth_year}) does not match the expected year for age range {age_range}. Off by {year_difference} years."

# Print matches and non-matches and their counts
for index, message in matches_dict.items():
    print(f"Match - Row {index}: {message}")

for index, message in non_matches_dict.items():
    print(f"Non-Match - Row {index}: {message}")

print(f"Total Matches: {matches}")
print(f"Total Non-Matches: {non_matches}")
# Out:
# Match - Row 2: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 3: Birth year (1960) matches the expected year for age range 55-64.
# Match - Row 4: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 5: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 6: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 7: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 8: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 9: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 10: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 11: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 12: Birth year (1975) matches the expected year for age range 45-54.
# Match - Row 13: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 14: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 15: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 16: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 17: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 18: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 19: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 20: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 21: Birth year (1983) matches the expected year for age range 35-44.
# Match - Row 22: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 23: Birth year (1974) matches the expected year for age range 45-54.
# Match - Row 24: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 25: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 26: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 28: Birth year (1999) matches the expected year for age range 18-24.
# Match - Row 29: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 30: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 31: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 32: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 33: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 34: Birth year (1952) matches the expected year for age range 65-75.
# Match - Row 35: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 36: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 37: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 38: Birth year (1998) matches the expected year for age range 25-34.
# Match - Row 40: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 41: Birth year (1975) matches the expected year for age range 45-54.
# Match - Row 42: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 43: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 44: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 45: Birth year (1961) matches the expected year for age range 55-64.
# Match - Row 46: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 47: Birth year (1983) matches the expected year for age range 35-44.
# Match - Row 48: Birth year (1965) matches the expected year for age range 55-64.
# Match - Row 49: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 50: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 51: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 52: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 53: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 54: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 56: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 57: Birth year (1967) matches the expected year for age range 55-64.
# Match - Row 58: Birth year (1976) matches the expected year for age range 45-54.
# Match - Row 59: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 60: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 61: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 62: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 63: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 64: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 65: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 66: Birth year (1962) matches the expected year for age range 55-64.
# Match - Row 67: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 68: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 69: Birth year (1974) matches the expected year for age range 45-54.
# Match - Row 70: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 71: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 72: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 73: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 74: Birth year (1981) matches the expected year for age range 35-44.
# Match - Row 75: Birth year (1959) matches the expected year for age range 55-64.
# Match - Row 76: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 77: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 78: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 79: Birth year (1966) matches the expected year for age range 55-64.
# Match - Row 80: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 81: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 82: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 83: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 84: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 86: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 87: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 88: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 89: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 90: Birth year (2004) matches the expected year for age range 18-24.
# Match - Row 91: Birth year (1964) matches the expected year for age range 55-64.
# Match - Row 92: Birth year (1970) matches the expected year for age range 45-54.
# Match - Row 93: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 94: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 95: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 96: Birth year (1981) matches the expected year for age range 35-44.
# Match - Row 97: Birth year (1944) matches the expected year for age range 75 years or older.
# Match - Row 98: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 99: Birth year (1965) matches the expected year for age range 55-64.
# Match - Row 100: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 101: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 102: Birth year (1963) matches the expected year for age range 55-64.
# Match - Row 103: Birth year (1968) matches the expected year for age range 45-54.
# Match - Row 104: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 105: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 106: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 107: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 108: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 109: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 110: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 111: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 112: Birth year (1976) matches the expected year for age range 45-54.
# Match - Row 113: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 114: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 115: Birth year (1961) matches the expected year for age range 55-64.
# Match - Row 116: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 117: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 118: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 119: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 120: Birth year (1973) matches the expected year for age range 45-54.
# Match - Row 121: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 122: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 123: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 124: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 125: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 126: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 127: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 128: Birth year (1961) matches the expected year for age range 55-64.
# Match - Row 129: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 130: Birth year (1967) matches the expected year for age range 55-64.
# Match - Row 131: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 133: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 134: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 135: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 136: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 137: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 138: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 139: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 140: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 141: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 142: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 143: Birth year (1960) matches the expected year for age range 55-64.
# Match - Row 144: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 145: Birth year (1960) matches the expected year for age range 55-64.
# Match - Row 147: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 148: Birth year (1970) matches the expected year for age range 45-54.
# Match - Row 149: Birth year (1955) matches the expected year for age range 65-75.
# Match - Row 150: Birth year (1960) matches the expected year for age range 55-64.
# Match - Row 151: Birth year (2000) matches the expected year for age range 18-24.
# Match - Row 152: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 153: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 154: Birth year (1969) matches the expected year for age range 45-54.
# Match - Row 155: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 156: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 157: Birth year (1966) matches the expected year for age range 55-64.
# Match - Row 158: Birth year (1961) matches the expected year for age range 55-64.
# Match - Row 159: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 161: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 162: Birth year (1966) matches the expected year for age range 55-64.
# Match - Row 163: Birth year (1975) matches the expected year for age range 45-54.
# Match - Row 164: Birth year (1964) matches the expected year for age range 55-64.
# Match - Row 165: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 166: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 167: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 168: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 169: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 170: Birth year (1999) matches the expected year for age range 18-24.
# Match - Row 171: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 172: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 173: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 176: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 177: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 178: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 179: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 180: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 181: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 182: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 183: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 184: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 186: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 187: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 188: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 189: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 190: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 191: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 192: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 193: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 194: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 196: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 197: Birth year (1970) matches the expected year for age range 45-54.
# Match - Row 198: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 199: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 200: Birth year (1968) matches the expected year for age range 45-54.
# Match - Row 201: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 202: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 203: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 206: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 207: Birth year (1968) matches the expected year for age range 45-54.
# Match - Row 208: Birth year (1963) matches the expected year for age range 55-64.
# Match - Row 209: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 210: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 211: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 212: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 213: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 214: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 215: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 216: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 217: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 219: Birth year (1958) matches the expected year for age range 55-64.
# Match - Row 220: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 221: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 222: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 223: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 224: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 225: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 226: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 227: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 228: Birth year (1975) matches the expected year for age range 45-54.
# Match - Row 230: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 231: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 232: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 233: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 234: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 235: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 236: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 237: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 238: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 239: Birth year (1968) matches the expected year for age range 45-54.
# Match - Row 240: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 241: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 242: Birth year (1960) matches the expected year for age range 55-64.
# Match - Row 243: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 244: Birth year (1959) matches the expected year for age range 55-64.
# Match - Row 245: Birth year (1969) matches the expected year for age range 45-54.
# Match - Row 247: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 248: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 249: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 251: Birth year (1983) matches the expected year for age range 35-44.
# Match - Row 252: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 253: Birth year (1970) matches the expected year for age range 45-54.
# Match - Row 255: Birth year (1962) matches the expected year for age range 55-64.
# Match - Row 256: Birth year (1974) matches the expected year for age range 45-54.
# Match - Row 257: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 258: Birth year (1974) matches the expected year for age range 45-54.
# Match - Row 259: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 260: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 261: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 262: Birth year (1973) matches the expected year for age range 45-54.
# Match - Row 263: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 264: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 265: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 266: Birth year (1969) matches the expected year for age range 45-54.
# Match - Row 267: Birth year (2000) matches the expected year for age range 18-24.
# Match - Row 268: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 269: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 270: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 271: Birth year (1970) matches the expected year for age range 45-54.
# Match - Row 272: Birth year (1973) matches the expected year for age range 45-54.
# Match - Row 273: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 274: Birth year (2003) matches the expected year for age range 18-24.
# Match - Row 275: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 276: Birth year (2004) matches the expected year for age range 18-24.
# Match - Row 277: Birth year (1963) matches the expected year for age range 55-64.
# Match - Row 278: Birth year (1955) matches the expected year for age range 65-75.
# Match - Row 279: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 280: Birth year (1975) matches the expected year for age range 45-54.
# Match - Row 281: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 282: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 285: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 286: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 287: Birth year (1970) matches the expected year for age range 45-54.
# Match - Row 288: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 289: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 290: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 292: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 293: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 294: Birth year (1999) matches the expected year for age range 18-24.
# Match - Row 295: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 296: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 297: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 298: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 299: Birth year (1957) matches the expected year for age range 65-75.
# Match - Row 300: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 301: Birth year (2000) matches the expected year for age range 18-24.
# Match - Row 302: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 304: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 305: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 306: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 307: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 308: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 309: Birth year (2003) matches the expected year for age range 18-24.
# Match - Row 311: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 312: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 313: Birth year (1964) matches the expected year for age range 55-64.
# Match - Row 314: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 315: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 316: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 317: Birth year (1988) matches the expected year for age range 35-44.
# Match - Row 318: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 319: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 320: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 321: Birth year (1973) matches the expected year for age range 45-54.
# Match - Row 322: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 323: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 324: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 325: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 326: Birth year (1964) matches the expected year for age range 55-64.
# Match - Row 327: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 328: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 329: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 330: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 332: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 333: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 334: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 335: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 336: Birth year (1954) matches the expected year for age range 65-75.
# Match - Row 337: Birth year (1975) matches the expected year for age range 45-54.
# Match - Row 339: Birth year (1976) matches the expected year for age range 45-54.
# Match - Row 340: Birth year (1968) matches the expected year for age range 55-64.
# Match - Row 341: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 342: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 343: Birth year (1963) matches the expected year for age range 55-64.
# Match - Row 344: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 345: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 346: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 347: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 348: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 349: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 350: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 351: Birth year (1969) matches the expected year for age range 45-54.
# Match - Row 352: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 353: Birth year (1952) matches the expected year for age range 65-75.
# Match - Row 354: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 355: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 356: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 358: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 359: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 361: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 362: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 363: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 364: Birth year (1981) matches the expected year for age range 35-44.
# Match - Row 365: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 366: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 367: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 368: Birth year (1958) matches the expected year for age range 55-64.
# Match - Row 369: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 370: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 371: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 372: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 373: Birth year (1968) matches the expected year for age range 55-64.
# Match - Row 374: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 375: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 376: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 377: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 378: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 379: Birth year (1969) matches the expected year for age range 45-54.
# Match - Row 381: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 382: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 383: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 384: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 385: Birth year (1950) matches the expected year for age range 65-75.
# Match - Row 386: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 387: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 388: Birth year (1964) matches the expected year for age range 55-64.
# Match - Row 389: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 390: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 391: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 392: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 393: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 394: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 395: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 396: Birth year (2002) matches the expected year for age range 18-24.
# Match - Row 397: Birth year (1967) matches the expected year for age range 55-64.
# Match - Row 398: Birth year (1965) matches the expected year for age range 55-64.
# Match - Row 399: Birth year (1971) matches the expected year for age range 45-54.
# Match - Row 400: Birth year (1974) matches the expected year for age range 45-54.
# Match - Row 401: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 402: Birth year (1999) matches the expected year for age range 18-24.
# Match - Row 403: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 404: Birth year (1961) matches the expected year for age range 55-64.
# Match - Row 405: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 406: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 407: Birth year (1960) matches the expected year for age range 55-64.
# Match - Row 408: Birth year (1969) matches the expected year for age range 45-54.
# Match - Row 409: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 410: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 411: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 412: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 413: Birth year (1968) matches the expected year for age range 55-64.
# Match - Row 414: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 415: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 416: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 417: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 418: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 419: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 420: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 421: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 422: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 423: Birth year (1966) matches the expected year for age range 55-64.
# Match - Row 424: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 425: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 426: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 427: Birth year (1979) matches the expected year for age range 35-44.
# Match - Row 428: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 429: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 430: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 431: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 432: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 433: Birth year (1965) matches the expected year for age range 55-64.
# Match - Row 435: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 436: Birth year (1981) matches the expected year for age range 35-44.
# Match - Row 437: Birth year (1988) matches the expected year for age range 35-44.
# Match - Row 438: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 439: Birth year (1963) matches the expected year for age range 55-64.
# Match - Row 440: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 441: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 442: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 443: Birth year (1976) matches the expected year for age range 45-54.
# Match - Row 444: Birth year (1973) matches the expected year for age range 45-54.
# Match - Row 445: Birth year (1952) matches the expected year for age range 65-75.
# Match - Row 446: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 447: Birth year (1986) matches the expected year for age range 35-44.
# Match - Row 448: Birth year (1981) matches the expected year for age range 35-44.
# Match - Row 449: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 450: Birth year (1969) matches the expected year for age range 45-54.
# Match - Row 451: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 452: Birth year (1968) matches the expected year for age range 45-54.
# Match - Row 453: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 454: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 455: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 456: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 457: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 458: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 459: Birth year (1976) matches the expected year for age range 45-54.
# Match - Row 460: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 461: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 462: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 463: Birth year (1988) matches the expected year for age range 35-44.
# Match - Row 464: Birth year (2000) matches the expected year for age range 18-24.
# Match - Row 465: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 466: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 467: Birth year (1974) matches the expected year for age range 45-54.
# Match - Row 468: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 469: Birth year (1966) matches the expected year for age range 55-64.
# Match - Row 470: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 471: Birth year (1993) matches the expected year for age range 25-34.
# Match - Row 472: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 473: Birth year (1983) matches the expected year for age range 35-44.
# Match - Row 474: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 475: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 476: Birth year (1962) matches the expected year for age range 55-64.
# Match - Row 477: Birth year (2003) matches the expected year for age range 18-24.
# Match - Row 478: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 479: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 480: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 481: Birth year (1976) matches the expected year for age range 45-54.
# Match - Row 482: Birth year (1970) matches the expected year for age range 45-54.
# Match - Row 483: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 484: Birth year (2002) matches the expected year for age range 18-24.
# Match - Row 485: Birth year (2000) matches the expected year for age range 18-24.
# Match - Row 486: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 487: Birth year (1965) matches the expected year for age range 55-64.
# Match - Row 488: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 489: Birth year (1974) matches the expected year for age range 45-54.
# Match - Row 490: Birth year (1981) matches the expected year for age range 35-44.
# Match - Row 491: Birth year (1948) matches the expected year for age range 65-75.
# Match - Row 492: Birth year (1971) matches the expected year for age range 45-54.
# Match - Row 493: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 494: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 495: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 496: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 497: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 498: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 499: Birth year (1963) matches the expected year for age range 55-64.
# Match - Row 500: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 501: Birth year (1999) matches the expected year for age range 18-24.
# Match - Row 502: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 503: Birth year (1959) matches the expected year for age range 55-64.
# Match - Row 504: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 505: Birth year (1999) matches the expected year for age range 18-24.
# Match - Row 506: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 507: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 508: Birth year (1978) matches the expected year for age range 35-44.
# Match - Row 509: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 512: Birth year (1991) matches the expected year for age range 25-34.
# Match - Row 513: Birth year (1961) matches the expected year for age range 55-64.
# Match - Row 514: Birth year (1990) matches the expected year for age range 25-34.
# Match - Row 515: Birth year (1994) matches the expected year for age range 25-34.
# Match - Row 516: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 517: Birth year (1998) matches the expected year for age range 18-24.
# Match - Row 518: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 519: Birth year (1980) matches the expected year for age range 35-44.
# Match - Row 520: Birth year (1963) matches the expected year for age range 55-64.
# Match - Row 521: Birth year (1997) matches the expected year for age range 25-34.
# Match - Row 522: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 523: Birth year (2000) matches the expected year for age range 18-24.
# Match - Row 524: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 525: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 526: Birth year (1957) matches the expected year for age range 65-75.
# Match - Row 527: Birth year (1987) matches the expected year for age range 35-44.
# Match - Row 528: Birth year (1983) matches the expected year for age range 35-44.
# Match - Row 529: Birth year (1960) matches the expected year for age range 55-64.
# Match - Row 530: Birth year (1976) matches the expected year for age range 45-54.
# Match - Row 531: Birth year (1995) matches the expected year for age range 25-34.
# Match - Row 532: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 533: Birth year (1996) matches the expected year for age range 25-34.
# Match - Row 534: Birth year (1982) matches the expected year for age range 35-44.
# Match - Row 535: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 537: Birth year (1988) matches the expected year for age range 25-34.
# Match - Row 539: Birth year (1972) matches the expected year for age range 45-54.
# Match - Row 540: Birth year (1989) matches the expected year for age range 25-34.
# Match - Row 541: Birth year (2001) matches the expected year for age range 18-24.
# Match - Row 542: Birth year (1955) matches the expected year for age range 65-75.
# Match - Row 543: Birth year (1984) matches the expected year for age range 35-44.
# Match - Row 544: Birth year (1971) matches the expected year for age range 45-54.
# Match - Row 545: Birth year (1971) matches the expected year for age range 45-54.
# Match - Row 546: Birth year (1992) matches the expected year for age range 25-34.
# Match - Row 547: Birth year (1977) matches the expected year for age range 45-54.
# Match - Row 548: Birth year (1985) matches the expected year for age range 35-44.
# Match - Row 549: Birth year (2003) matches the expected year for age range 18-24.
# Match - Row 550: Birth year (1992) matches the expected year for age range 25-34.
# Non-Match - Row 27: Birth year (1978) does not match the expected year for age range 25-34. Off by 10 years.
# Non-Match - Row 39: Birth year (1974) does not match the expected year for age range 35-44. Off by 4 years.
# Non-Match - Row 55: Birth year (1987) does not match the expected year for age range 25-34. Off by 1 years.
# Non-Match - Row 85: Birth year (1985) does not match the expected year for age range 25-34. Off by 3 years.
# Non-Match - Row 132: Birth year (1987) does not match the expected year for age range 25-34. Off by 1 years.
# Non-Match - Row 146: Birth year (1970) does not match the expected year for age range 35-44. Off by 8 years.
# Non-Match - Row 160: Birth year (1980) does not match the expected year for age range 25-34. Off by 8 years.
# Non-Match - Row 174: Birth year (1969) does not match the expected year for age range 55-64. Off by 1 years.
# Non-Match - Row 175: Birth year (1955) does not match the expected year for age range 55-64. Off by 3 years.
# Non-Match - Row 185: Birth year (1993) does not match the expected year for age range 35-44. Off by 5 years.
# Non-Match - Row 195: Birth year (1961) does not match the expected year for age range 65-75. Off by 3 years.
# Non-Match - Row 204: Birth year (1990) does not match the expected year for age range 35-44. Off by 2 years.
# Non-Match - Row 205: Birth year (1987) does not match the expected year for age range 25-34. Off by 1 years.
# Non-Match - Row 218: Birth year (1977) does not match the expected year for age range 35-44. Off by 1 years.
# Non-Match - Row 229: Birth year (2000) does not match the expected year for age range 25-34. Off by 2 years.
# Non-Match - Row 246: Birth year (1994) does not match the expected year for age range 18-24. Off by 4 years.
# Non-Match - Row 250: Birth year (1980) does not match the expected year for age range 45-54. Off by 2 years.
# Non-Match - Row 254: Birth year (1964) does not match the expected year for age range 35-44. Off by 14 years.
# Non-Match - Row 283: Birth year (1970) does not match the expected year for age range 35-44. Off by 8 years.
# Non-Match - Row 284: Birth year (1984) does not match the expected year for age range 45-54. Off by 6 years.
# Non-Match - Row 291: Birth year (1982) does not match the expected year for age range 25-34. Off by 6 years.
# Non-Match - Row 303: Birth year (1987) does not match the expected year for age range 25-34. Off by 1 years.
# Non-Match - Row 310: Birth year (1962) does not match the expected year for age range 65-75. Off by 4 years.
# Non-Match - Row 331: Birth year (1991) does not match the expected year for age range 35-44. Off by 3 years.
# Non-Match - Row 338: Birth year (1971) does not match the expected year for age range 55-64. Off by 3 years.
# Non-Match - Row 357: Birth year (2001) does not match the expected year for age range 25-34. Off by 3 years.
# Non-Match - Row 360: Birth year (1987) does not match the expected year for age range 25-34. Off by 1 years.
# Non-Match - Row 380: Birth year (1990) does not match the expected year for age range 45-54. Off by 12 years.
# Non-Match - Row 434: Birth year (1999) does not match the expected year for age range 25-34. Off by 1 years.
# Non-Match - Row 510: Birth year (1997) does not match the expected year for age range 18-24. Off by 1 years.
# Non-Match - Row 511: Birth year (1955) does not match the expected year for age range 55-64. Off by 3 years.
# Non-Match - Row 536: Birth year (1987) does not match the expected year for age range 25-34. Off by 1 years.
# Non-Match - Row 538: Birth year (1967) does not match the expected year for age range 35-44. Off by 11 years.
# Total Matches: 516
# Total Non-Matches: 33
